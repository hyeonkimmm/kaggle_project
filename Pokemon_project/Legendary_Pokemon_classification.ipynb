# %% [markdown]
# # Pokemon_eda & Legendary Pokemon classification

# %% [markdown]
# ## Load Data

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import os
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
#plt.rcParams.update({'font.size': 22}) # matplot fontsize 고정
csv_path = os.getenv("HOME") +"/kaggle_project/Pokemon_project/data/Pokemon.csv"
original_data = pd.read_csv(csv_path)

# original data backup
pokemon = original_data.copy()
print(pokemon.shape)
print(pokemon.head())
pokemon.columns
# Out:
# (800, 13)
#    #                   Name Type 1  ... Speed  Generation  Legendary
# 0  1              Bulbasaur  Grass  ...    45           1      False
# 1  2                Ivysaur  Grass  ...    60           1      False
# 2  3               Venusaur  Grass  ...    80           1      False
# 3  3  VenusaurMega Venusaur  Grass  ...    80           1      False
# 4  4             Charmander   Fire  ...    65           1      False
#
# [5 rows x 13 columns]
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
# 전설의 포켓몬 데이터셋
legendary = pokemon[pokemon["Legendary"] == True].reset_index(drop=True)
print(legendary.shape)
legendary.head()
# Out:
# (65, 13)
#      #                 Name    Type 1  ... Speed  Generation  Legendary
# 0  144             Articuno       Ice  ...    85           1       True
# 1  145               Zapdos  Electric  ...   100           1       True
# 2  146              Moltres      Fire  ...    90           1       True
# 3  150               Mewtwo   Psychic  ...   130           1       True
# 4  150  MewtwoMega Mewtwo X   Psychic  ...   130           1       True
#
# [5 rows x 13 columns]

# %%
# 일반 포켓몬 데이터셋
ordinary = pokemon[pokemon["Legendary"] == False].reset_index(drop=True)
print(ordinary.shape)
ordinary.head()
# Out:
# (735, 13)
#    #                   Name Type 1  ... Speed  Generation  Legendary
# 0  1              Bulbasaur  Grass  ...    45           1      False
# 1  2                Ivysaur  Grass  ...    60           1      False
# 2  3               Venusaur  Grass  ...    80           1      False
# 3  3  VenusaurMega Venusaur  Grass  ...    80           1      False
# 4  4             Charmander   Fire  ...    65           1      False
#
# [5 rows x 13 columns]

# %% [markdown]
# ## Check columns

# %%
pokemon.isnull().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
print(len(pokemon.columns))
pokemon.columns
# Out:
# 13
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# - **#**: 포켓몬 Id number. 같은 포켓몬이지만 성별이 다른 경우 등은 같은 #값을 가진다. `int`
#
#
# - **Name** : 포켓몬 이름. 포켓몬 각각의 이름으로, 이름 데이터는 800개의 포켓몬이 모두 다르다. (unique) `str`
#
#
# - **Type 1** : 첫 번째 속성. 속성을 하나만 가지는 경우 Type 1에 입력된다. `str`
#
#
# - **Type 2** : 두 번째 속성. 속성을 하나만 가지는 포켓몬의 경우 Type 2는 NaN(결측값)을 가진다. `str`
#
#
# - **Total** : 전체 6가지 스탯의 총합. `int`
#
#
# - **HP** : 포켓몬의 체력. `int`
#
#
# - **Attack** : 물리 공격력. (scratch, punch 등) `int`
#
#
# - **Defense** : 물리 공격에 대한 방어력. `int`
#
#
# - **Sp. Atk** : 특수공격력. (fire blast, bubble beam 등) `int`
#
#
# - **Sp. Def** : 특수공격에 대한 방어력. `int`
#
#
# - **Speed** : 포켓몬 매치에 대해 어떤 포켓몬이 먼저 공격할지를 결정. (더 높은 포켓몬이 먼저 공격한다) `int`
#
#
# - **Generation** : 포켓몬의 세대. 현재 데이터에는 6세대까지 있다. `int`
#
#
# - **Legendary** : 전설의 포켓몬 여부. !! Target feature !! `bool`

# %% [markdown]
# ### ID number

# %%
len(set(pokemon["#"]))
# Out:
# 721

# %%
pokemon[pokemon["#"] == 6]
# Out:
#    #                       Name Type 1  ... Speed  Generation  Legendary
# 6  6                  Charizard   Fire  ...   100           1      False
# 7  6  CharizardMega Charizard X   Fire  ...   100           1      False
# 8  6  CharizardMega Charizard Y   Fire  ...   100           1      False
#
# [3 rows x 13 columns]

# %% [markdown]
# ### Name

# %%
len(set(pokemon["Name"]))
# Out:
# 800

# %% [markdown]
# ### Type1 & Type2

# %%
pokemon.loc[[6, 10]]
# Out:
#     #       Name Type 1  Type 2  ...  Sp. Def  Speed  Generation  Legendary
# 6   6  Charizard   Fire  Flying  ...       85    100           1      False
# 10  8  Wartortle  Water     NaN  ...       80     58           1      False
#
# [2 rows x 13 columns]

# %%
len(list(set(pokemon["Type 1"]))), len(list(set(pokemon["Type 2"])))
# Out:
# (18, 19)

# %%
set(pokemon["Type 2"]) - set(pokemon["Type 1"])
# Out:
# {nan}

# %%
types = list(set(pokemon["Type 1"]))
print(len(types))
print(types)
# Out:
# 18
# ['Grass', 'Rock', 'Ghost', 'Fire', 'Ground', 'Ice', 'Fighting', 'Electric', 'Dragon', 'Steel', 'Bug', 'Normal', 'Poison', 'Psychic', 'Flying', 'Dark', 'Water', 'Fairy']

# %%
# 데이터가 비어있는 `NAN`의 개수를 확인하고 싶을 때는 isna()함수를 활용합니다
pokemon["Type 2"].isna().isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Name: Type 2, Length: 800, dtype: bool

# %%
plt.figure(figsize=(18, 10))

plt.subplot(211)
sns.countplot(data=ordinary, x="Type 1", order=types).set_xlabel('')
plt.title("[All Pokemons]")

plt.subplot(212)
sns.countplot(data=legendary, x="Type 1", order=types).set_xlabel('')
plt.title("[Legendary Pokemons]")

plt.show()

# %%
# Type1별로 Legendary 의 비율을 보여주는 피벗 테이블
pd.pivot_table(pokemon, index="Type 1", values="Legendary").sort_values(by=["Legendary"], ascending=False)
# Out:
#           Legendary
# Type 1
# Flying     0.500000
# Dragon     0.375000
# Psychic    0.245614
# Steel      0.148148
# Ground     0.125000
# Fire       0.096154
# Electric   0.090909
# Rock       0.090909
# Ice        0.083333
# Dark       0.064516
# Ghost      0.062500
# Fairy      0.058824
# Grass      0.042857
# Water      0.035714
# Normal     0.020408
# Poison     0.000000
# Fighting   0.000000
# Bug        0.000000

# %%
plt.figure(figsize=(18, 10))

plt.subplot(211)
sns.countplot(data=ordinary, x="Type 2", order=types).set_xlabel('')
plt.title("[All Pokemons]")

plt.subplot(212)
sns.countplot(data=legendary, x="Type 2", order=types).set_xlabel('')
plt.title("[Legendary Pokemons]")

plt.show()

# %%
# Type2별로 Legendary 의 비율을 보여주는 피벗 테이블
pd.pivot_table(pokemon, index="Type 2", values="Legendary").sort_values(by=["Legendary"], ascending=False)
# Out:
#           Legendary
# Type 2
# Fire       0.250000
# Dragon     0.222222
# Ice        0.214286
# Electric   0.166667
# Fighting   0.153846
# Psychic    0.151515
# Flying     0.134021
# Fairy      0.086957
# Water      0.071429
# Ghost      0.071429
# Dark       0.050000
# Steel      0.045455
# Ground     0.028571
# Rock       0.000000
# Bug        0.000000
# Poison     0.000000
# Normal     0.000000
# Grass      0.000000

# %% [markdown]
# ## Total

# %%
stats = ["HP", "Attack", "Defense", "Sp. Atk", "Sp. Def", "Speed"]
stats
# Out:
# ['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']

# %%
print("#0 pokemon: {}\n".format(pokemon.loc[0, "Name"]))
print("total: ", int(pokemon.loc[0, "Total"]))
print("stats: ", list(pokemon.loc[0, stats]))
print("sum of all stats: ", sum(list(pokemon.loc[0, stats])))
# Out:
# #0 pokemon: Bulbasaur
#
# total:  318
# stats:  [45, 49, 49, 65, 65, 45]
# sum of all stats:  318

# %%
# axis = 1 포켓몬별로 가로 방향으로 더해야 하기 때문에 추가
sum(pokemon['Total'].values == pokemon[stats].values.sum(axis=1))
# Out:
# 800

# %%
fig, ax = plt.subplots()
fig.set_size_inches(18, 6)

sns.scatterplot(data=pokemon, x="Type 1", y="Total", hue="Legendary")
plt.show()

# %%
figure, ((ax1, ax2), (ax3, ax4), (ax5, ax6)) = plt.subplots(nrows=3, ncols=2)
figure.set_size_inches(18, 18)

sns.scatterplot(data=pokemon, y="Total", x="HP", hue="Legendary", ax=ax1)
sns.scatterplot(data=pokemon, y="Total", x="Attack", hue="Legendary", ax=ax2)
sns.scatterplot(data=pokemon, y="Total", x="Defense", hue="Legendary", ax=ax3)
sns.scatterplot(data=pokemon, y="Total", x="Sp. Atk", hue="Legendary", ax=ax4)
sns.scatterplot(data=pokemon, y="Total", x="Sp. Def", hue="Legendary", ax=ax5)
sns.scatterplot(data=pokemon, y="Total", x="Speed", hue="Legendary", ax=ax6)
plt.show()

# %% [markdown]
# ### Generation

# %%
plt.figure(figsize=(18, 10))

plt.subplot(211)
sns.countplot(data=ordinary, x="Generation").set_xlabel('')
plt.title("[All Pkemons]")
plt.subplot(212)
sns.countplot(data=legendary, x="Generation").set_xlabel('')
plt.title("[Legendary Pkemons]")
plt.show()

# %%
#plt.rcParams.update({'font.size': 22})
fig, ax = plt.subplots()
fig.set_size_inches(8, 4)

sns.scatterplot(data=legendary, y="Type 1", x="Total")
plt.show()

# %%
sorted(list(set(legendary["Total"])))
# Out:
# [580, 600, 660, 670, 680, 700, 720, 770, 780]

# %%
fig, ax = plt.subplots()
fig.set_size_inches(8, 4)

sns.countplot(data=legendary, x="Total")
plt.show()

# %%
round(65 / 9, 2)
# Out:
# 7.22

# %%
print(sorted(list(set(ordinary["Total"]))))
len(sorted(list(set(ordinary["Total"]))))
# Out:
# [180, 190, 194, 195, 198, 200, 205, 210, 213, 215, 218, 220, 224, 236, 237, 240, 244, 245, 250, 251, 253, 255, 260, 262, 263, 264, 265, 266, 269, 270, 273, 275, 278, 280, 281, 285, 288, 289, 290, 292, 294, 295, 299, 300, 302, 303, 304, 305, 306, 307, 308, 309, 310, 313, 314, 315, 316, 318, 319, 320, 323, 325, 328, 329, 330, 334, 335, 336, 340, 341, 345, 348, 349, 350, 351, 352, 355, 358, 360, 362, 363, 365, 369, 370, 371, 375, 380, 382, 384, 385, 390, 395, 400, 401, 405, 409, 410, 411, 413, 414, 415, 418, 420, 423, 424, 425, 428, 430, 431, 435, 438, 440, 442, 445, 446, 448, 450, 452, 454, 455, 456, 458, 460, 461, 462, 464, 465, 466, 467, 468, 470, 471, 472, 473, 474, 475, 479, 480, 481, 482, 483, 484, 485, 487, 488, 489, 490, 494, 495, 497, 498, 499, 500, 505, 507, 508, 509, 510, 514, 515, 518, 519, 520, 521, 523, 525, 528, 530, 531, 534, 535, 540, 545, 550, 552, 555, 560, 565, 567, 575, 579, 580, 590, 594, 600, 610, 615, 618, 625, 630, 634, 635, 640, 670, 700]
# 195

# %%
round(735 / 195, 2)
# Out:
# 3.77

# %% [markdown]
# - `Total`값의 다양성은 일반 포켓몬이 전설의 포켓몬보다 두 배 가까이 된다. 즉 전설의 포켓몬의 `Total`값은 다양하지 않다.
#     : **한 포켓몬의 `Total` 속성값이 전설의 포켓몬의 값들 집합에 포함되는지의 여부**는 전설의 포켓몬임을 결정하는 데에 영향을 미친다.
#
#
# - 또한, **전설의 포켓몬의 `Total` 값 중에는 일반 포켓몬이 가지지 못하는 `Total`값이 존재**한다. ex) 680, 720, 770, 780
#     : `Total`값은 전설의 포켓몬인지 아닌지를 결정하는 데에 이러한 방식으로도 영향을 미칠 수 있다.
#
#
# 즉, **`Total`값은 `legendary`인지 아닌지를 예측하는 데에 중요한 컬럼일 것**이라는 결론을 내릴 수 있습니다.

# %% [markdown]
# ## Name EDA

# %%
n1, n2, n3, n4, n5 = legendary[3:6], legendary[14:24], legendary[25:29], legendary[46:50], legendary[52:57]
names = pd.concat([n1, n2, n3, n4, n5]).reset_index(drop=True)
names
# Out:
#       #                      Name    Type 1  ... Speed  Generation  Legendary
# 0   150                    Mewtwo   Psychic  ...   130           1       True
# 1   150       MewtwoMega Mewtwo X   Psychic  ...   130           1       True
# 2   150       MewtwoMega Mewtwo Y   Psychic  ...   140           1       True
# 3   380                    Latias    Dragon  ...   110           3       True
# 4   380         LatiasMega Latias    Dragon  ...   110           3       True
# 5   381                    Latios    Dragon  ...   110           3       True
# 6   381         LatiosMega Latios    Dragon  ...   110           3       True
# 7   382                    Kyogre     Water  ...    90           3       True
# 8   382       KyogrePrimal Kyogre     Water  ...    90           3       True
# 9   383                   Groudon    Ground  ...    90           3       True
# 10  383     GroudonPrimal Groudon    Ground  ...    90           3       True
# 11  384                  Rayquaza    Dragon  ...    95           3       True
# 12  384     RayquazaMega Rayquaza    Dragon  ...   115           3       True
# 13  386        DeoxysNormal Forme   Psychic  ...   150           3       True
# 14  386        DeoxysAttack Forme   Psychic  ...   150           3       True
# 15  386       DeoxysDefense Forme   Psychic  ...    90           3       True
# 16  386         DeoxysSpeed Forme   Psychic  ...   180           3       True
# 17  641   TornadusIncarnate Forme    Flying  ...   111           5       True
# 18  641     TornadusTherian Forme    Flying  ...   121           5       True
# 19  642  ThundurusIncarnate Forme  Electric  ...   111           5       True
# 20  642    ThundurusTherian Forme  Electric  ...   101           5       True
# 21  645   LandorusIncarnate Forme    Ground  ...   101           5       True
# 22  645     LandorusTherian Forme    Ground  ...    91           5       True
# 23  646                    Kyurem    Dragon  ...    95           5       True
# 24  646        KyuremBlack Kyurem    Dragon  ...    95           5       True
# 25  646        KyuremWhite Kyurem    Dragon  ...    95           5       True
#
# [26 rows x 13 columns]

# %% [markdown]
# ## Long Name

# %%
legendary["name_count"] = legendary["Name"].apply(lambda i: len(i))    
legendary.head()
# Out:
#      #                 Name    Type 1  ... Generation  Legendary  name_count
# 0  144             Articuno       Ice  ...          1       True           8
# 1  145               Zapdos  Electric  ...          1       True           6
# 2  146              Moltres      Fire  ...          1       True           7
# 3  150               Mewtwo   Psychic  ...          1       True           6
# 4  150  MewtwoMega Mewtwo X   Psychic  ...          1       True          19
#
# [5 rows x 14 columns]

# %%
ordinary["name_count"] = ordinary["Name"].apply(lambda i: len(i))    
ordinary.head()
# Out:
#    #                   Name Type 1  ... Generation  Legendary  name_count
# 0  1              Bulbasaur  Grass  ...          1      False           9
# 1  2                Ivysaur  Grass  ...          1      False           7
# 2  3               Venusaur  Grass  ...          1      False           8
# 3  3  VenusaurMega Venusaur  Grass  ...          1      False          21
# 4  4             Charmander   Fire  ...          1      False          10
#
# [5 rows x 14 columns]

# %%
plt.figure(figsize=(18, 10))

plt.subplot(211)
sns.countplot(data=legendary, x="name_count").set_xlabel('')
plt.title("Legendary")
plt.subplot(212)
sns.countplot(data=ordinary, x="name_count").set_xlabel('')
plt.title("Ordinary")
plt.show()

# %%
print(round(len(legendary[legendary["name_count"] > 9]) / len(legendary) * 100, 2), "%")
# Out:
# 41.54 %

# %%
print(round(len(ordinary[ordinary["name_count"] > 9]) / len(ordinary) * 100, 2), "%")
# Out:
# 15.65 %

# %% [markdown]
# **전설의 포켓몬의 이름이 10 이상일 확률은 41%**를 넘는 반면에, **일반 포켓몬의 이름이 10 이상일 확률은 약 16%** 밖에 안됨을 확인할 수 있습니다!
#
# 이는 아주 큰 차이이므로 legendary인지 아닌지를 구분하는 데에 큰 의미가 있습니다.
#
#
# 위의 두 가지, 이름에 대한 분석은 중요한 시사점을 가집니다.
#
#
# - **만약 "Latios"가 전설의 포켓몬이라면, "%%% Latios" 또한 전설의 포켓몬이다!**
# - **적어도 전설의 포켓몬에서 높은 빈도를 보이는 이름들의 모임이 존재한다!**
# - **전설의 포켓몬은 긴 이름을 가졌을 확률이 높다!**

# %% [markdown]
# ## Data Pre Processing

# %%
pokemon["name_count"] = pokemon["Name"].apply(lambda i: len(i))
pokemon.head()
# Out:
#    #                   Name Type 1  ... Generation  Legendary  name_count
# 0  1              Bulbasaur  Grass  ...          1      False           9
# 1  2                Ivysaur  Grass  ...          1      False           7
# 2  3               Venusaur  Grass  ...          1      False           8
# 3  3  VenusaurMega Venusaur  Grass  ...          1      False          21
# 4  4             Charmander   Fire  ...          1      False          10
#
# [5 rows x 14 columns]

# %%
pokemon["long_name"] = pokemon["name_count"] >= 10
pokemon.head()
# Out:
#    #                   Name Type 1  ... Legendary  name_count  long_name
# 0  1              Bulbasaur  Grass  ...     False           9      False
# 1  2                Ivysaur  Grass  ...     False           7      False
# 2  3               Venusaur  Grass  ...     False           8      False
# 3  3  VenusaurMega Venusaur  Grass  ...     False          21       True
# 4  4             Charmander   Fire  ...     False          10       True
#
# [5 rows x 15 columns]

# %%
pokemon["Name_nospace"] = pokemon["Name"].apply(lambda i: i.replace(" ", ""))
pokemon.tail()
# Out:
#        #                 Name  ... long_name        Name_nospace
# 795  719              Diancie  ...     False             Diancie
# 796  719  DiancieMega Diancie  ...      True  DiancieMegaDiancie
# 797  720  HoopaHoopa Confined  ...      True  HoopaHoopaConfined
# 798  720   HoopaHoopa Unbound  ...      True   HoopaHoopaUnbound
# 799  721            Volcanion  ...     False           Volcanion
#
# [5 rows x 16 columns]

# %%
pokemon["name_isalpha"] = pokemon["Name_nospace"].apply(lambda i: i.isalpha())
pokemon.head()
# Out:
#    #                   Name  ...          Name_nospace name_isalpha
# 0  1              Bulbasaur  ...             Bulbasaur         True
# 1  2                Ivysaur  ...               Ivysaur         True
# 2  3               Venusaur  ...              Venusaur         True
# 3  3  VenusaurMega Venusaur  ...  VenusaurMegaVenusaur         True
# 4  4             Charmander  ...            Charmander         True
#
# [5 rows x 17 columns]

# %%
print(pokemon[pokemon["name_isalpha"] == False].shape)
pokemon[pokemon["name_isalpha"] == False]
# Out:
# (9, 17)
#        #              Name   Type 1  ... long_name     Name_nospace  name_isalpha
# 34    29          Nidoran♀   Poison  ...     False         Nidoran♀         False
# 37    32          Nidoran♂   Poison  ...     False         Nidoran♂         False
# 90    83        Farfetch'd   Normal  ...      True       Farfetch'd         False
# 131  122          Mr. Mime  Psychic  ...     False          Mr.Mime         False
# 252  233          Porygon2   Normal  ...     False         Porygon2         False
# 270  250             Ho-oh     Fire  ...     False            Ho-oh         False
# 487  439          Mime Jr.  Psychic  ...     False          MimeJr.         False
# 525  474         Porygon-Z   Normal  ...     False        Porygon-Z         False
# 794  718  Zygarde50% Forme   Dragon  ...      True  Zygarde50%Forme         False
#
# [9 rows x 17 columns]

# %%
pokemon = pokemon.replace(to_replace="Nidoran♀", value="Nidoran X")
pokemon = pokemon.replace(to_replace="Nidoran♂", value="Nidoran Y")
pokemon = pokemon.replace(to_replace="Farfetch'd", value="Farfetchd")
pokemon = pokemon.replace(to_replace="Mr. Mime", value="Mr Mime")
pokemon = pokemon.replace(to_replace="Porygon2", value="Porygon")
pokemon = pokemon.replace(to_replace="Ho-oh", value="Ho Oh")
pokemon = pokemon.replace(to_replace="Mime Jr.", value="Mime Jr")
pokemon = pokemon.replace(to_replace="Porygon-Z", value="Porygon Z")
pokemon = pokemon.replace(to_replace="Zygarde50% Forme", value="Zygarde Forme")

pokemon.loc[[34, 37, 90, 131, 252, 270, 487, 525, 794]]
# Out:
#        #           Name   Type 1  ... long_name     Name_nospace  name_isalpha
# 34    29      Nidoran X   Poison  ...     False        Nidoran X         False
# 37    32      Nidoran Y   Poison  ...     False        Nidoran Y         False
# 90    83      Farfetchd   Normal  ...      True        Farfetchd         False
# 131  122        Mr Mime  Psychic  ...     False          Mr.Mime         False
# 252  233        Porygon   Normal  ...     False          Porygon         False
# 270  250          Ho Oh     Fire  ...     False            Ho Oh         False
# 487  439        Mime Jr  Psychic  ...     False          MimeJr.         False
# 525  474      Porygon Z   Normal  ...     False        Porygon Z         False
# 794  718  Zygarde Forme   Dragon  ...      True  Zygarde50%Forme         False
#
# [9 rows x 17 columns]

# %%
pokemon["Name_nospace"] = pokemon["Name"].apply(lambda i: i.replace(" ", ""))
pokemon["name_isalpha"] = pokemon["Name_nospace"].apply(lambda i: i.isalpha())
pokemon[pokemon["name_isalpha"] == False]
# Out:
# Empty DataFrame
# Columns: [#, Name, Type 1, Type 2, Total, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed, Generation, Legendary, name_count, long_name, Name_nospace, name_isalpha]
# Index: []

# %% [markdown]
# ## 정규표현식

# %%
import re
name = "CharizardMega Charizard X"
name_split = name.split(" ")
name_split
# Out:
# ['CharizardMega', 'Charizard', 'X']

# %%
temp = name_split[0]
tokens = re.findall('[A-Z][a-z]*', temp)
tokens
# Out:
# ['Charizard', 'Mega']

# %% [markdown]
# 성공적으로 잘렸군요!
# 여기서 `[A-Z][a-z]*` 라는 이상한 패턴이 쓰였습니다! 이것이 바로 정규표현식입니다.
#
# 세부 의미는 다음과 같습니다.
#
# - `[A-Z]` : `A`부터 `Z`까지의 대문자 중 한 가지로 시작하고,
# - `[a-z]` : 그 뒤에 `a`부터 `z`까지의 소문자 중 한 가지가 붙는데,
# - `*` : 그 소문자의 개수는 하나 이상인 패턴 (`*`는 정규표현식 중에서 "반복"을 나타내는 기호)

# %%
tokens = []
for part_name in name_split:
    a = re.findall('[A-Z][a-z]*', part_name)
    tokens.extend(a)
tokens
# Out:
# ['Charizard', 'Mega', 'Charizard', 'X']

# %%
def tokenize(name):
    name_split = name.split(" ")
    
    tokens = []
    for part_name in name_split:
        a = re.findall('[A-Z][a-z]*', part_name)
        tokens.extend(a)
        
    return np.array(tokens)

# %%
name = "CharizardMega Charizard X"
tokenize(name)
# Out:
# array(['Charizard', 'Mega', 'Charizard', 'X'], dtype='<U9')

# %%
all_tokens = list(legendary["Name"].apply(tokenize).values)

token_set = []
for token in all_tokens:
    token_set.extend(token)

print(len(set(token_set)))
print(token_set)
# Out:
# 65
# ['Articuno', 'Zapdos', 'Moltres', 'Mewtwo', 'Mewtwo', 'Mega', 'Mewtwo', 'X', 'Mewtwo', 'Mega', 'Mewtwo', 'Y', 'Raikou', 'Entei', 'Suicune', 'Lugia', 'Ho', 'Regirock', 'Regice', 'Registeel', 'Latias', 'Latias', 'Mega', 'Latias', 'Latios', 'Latios', 'Mega', 'Latios', 'Kyogre', 'Kyogre', 'Primal', 'Kyogre', 'Groudon', 'Groudon', 'Primal', 'Groudon', 'Rayquaza', 'Rayquaza', 'Mega', 'Rayquaza', 'Jirachi', 'Deoxys', 'Normal', 'Forme', 'Deoxys', 'Attack', 'Forme', 'Deoxys', 'Defense', 'Forme', 'Deoxys', 'Speed', 'Forme', 'Uxie', 'Mesprit', 'Azelf', 'Dialga', 'Palkia', 'Heatran', 'Regigigas', 'Giratina', 'Altered', 'Forme', 'Giratina', 'Origin', 'Forme', 'Darkrai', 'Shaymin', 'Land', 'Forme', 'Shaymin', 'Sky', 'Forme', 'Arceus', 'Victini', 'Cobalion', 'Terrakion', 'Virizion', 'Tornadus', 'Incarnate', 'Forme', 'Tornadus', 'Therian', 'Forme', 'Thundurus', 'Incarnate', 'Forme', 'Thundurus', 'Therian', 'Forme', 'Reshiram', 'Zekrom', 'Landorus', 'Incarnate', 'Forme', 'Landorus', 'Therian', 'Forme', 'Kyurem', 'Kyurem', 'Black', 'Kyurem', 'Kyurem', 'White', 'Kyurem', 'Xerneas', 'Yveltal', 'Zygarde', 'Forme', 'Diancie', 'Diancie', 'Mega', 'Diancie', 'Hoopa', 'Hoopa', 'Confined', 'Hoopa', 'Hoopa', 'Unbound', 'Volcanion']

# %% [markdown]
# ### Counter

# %%
from collections import Counter
a = [1, 1, 0, 0, 0, 1, 1, 2, 3]
Counter(a)
# Out:
# Counter({1: 4, 0: 3, 2: 1, 3: 1})

# %%
Counter(a).most_common()
# Out:
# [(1, 4), (0, 3), (2, 1), (3, 1)]

# %%
most_common = Counter(token_set).most_common(10)
most_common
# Out:
# [('Forme', 15),
#  ('Mega', 6),
#  ('Mewtwo', 5),
#  ('Kyurem', 5),
#  ('Deoxys', 4),
#  ('Hoopa', 4),
#  ('Latias', 3),
#  ('Latios', 3),
#  ('Kyogre', 3),
#  ('Groudon', 3)]

# %%
for token, _ in most_common:
    pokemon[token] = pokemon["Name"].str.contains(token)

pokemon.head(10)
# Out:
#    #                       Name Type 1  Type 2  ...  Latias  Latios  Kyogre  Groudon
# 0  1                  Bulbasaur  Grass  Poison  ...   False   False   False    False
# 1  2                    Ivysaur  Grass  Poison  ...   False   False   False    False
# 2  3                   Venusaur  Grass  Poison  ...   False   False   False    False
# 3  3      VenusaurMega Venusaur  Grass  Poison  ...   False   False   False    False
# 4  4                 Charmander   Fire     NaN  ...   False   False   False    False
# 5  5                 Charmeleon   Fire     NaN  ...   False   False   False    False
# 6  6                  Charizard   Fire  Flying  ...   False   False   False    False
# 7  6  CharizardMega Charizard X   Fire  Dragon  ...   False   False   False    False
# 8  6  CharizardMega Charizard Y   Fire  Flying  ...   False   False   False    False
# 9  7                   Squirtle  Water     NaN  ...   False   False   False    False
#
# [10 rows x 27 columns]

# %% [markdown]
# ## Type1 & 2 전처리하기

# %%
print(len(types))
# Out:
# 18

# %% [markdown]
# ### one - hot encoding

# %%
for t in types:
    pokemon[t] = (pokemon["Type 1"] == t) | (pokemon["Type 2"] == t)
    
pokemon[[["Type 1", "Type 2"] + types][0]].tail()
# Out:
#       Type 1 Type 2  Grass   Rock  Ghost  ...  Psychic  Flying   Dark  Water  Fairy
# 795     Rock  Fairy  False   True  False  ...    False   False  False  False   True
# 796     Rock  Fairy  False   True  False  ...    False   False  False  False   True
# 797  Psychic  Ghost  False  False   True  ...     True   False  False  False  False
# 798  Psychic   Dark  False  False  False  ...     True   False   True  False  False
# 799     Fire  Water  False  False  False  ...    False   False  False   True  False
#
# [5 rows x 20 columns]

# %% [markdown]
# ## Base Line Model

# %%
print(original_data.shape)
original_data.head()
# Out:
# (800, 13)
#    #                   Name Type 1  ... Speed  Generation  Legendary
# 0  1              Bulbasaur  Grass  ...    45           1      False
# 1  2                Ivysaur  Grass  ...    60           1      False
# 2  3               Venusaur  Grass  ...    80           1      False
# 3  3  VenusaurMega Venusaur  Grass  ...    80           1      False
# 4  4             Charmander   Fire  ...    65           1      False
#
# [5 rows x 13 columns]

# %%
original_data.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
features = ['Total', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Generation']

# %%
target = 'Legendary'

# %%
X = original_data[features]
print(X.shape)
X.head()
# Out:
# (800, 8)
#    Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# 0    318  45      49       49       65       65     45           1
# 1    405  60      62       63       80       80     60           1
# 2    525  80      82       83      100      100     80           1
# 3    625  80     100      123      122      120     80           1
# 4    309  39      52       43       60       50     65           1

# %%
y = original_data[target]
print(y.shape)
y.head()
# Out:
# (800,)
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Legendary, dtype: bool

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=15)

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (640, 8) (640,)
# (160, 8) (160,)

# %% [markdown]
# ### Decision tree

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(random_state=25)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[144,   3],
#        [  5,   8]])

# %%
len(legendary)
# Out:
# 65

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.97      0.98      0.97       147
#         True       0.73      0.62      0.67        13
#
#     accuracy                           0.95       160
#    macro avg       0.85      0.80      0.82       160
# weighted avg       0.95      0.95      0.95       160

# %% [markdown]
# Recall 값이 낮다. -> FN 이 높다 전설의 포켓몬인데 일반 포켓몬이라고 판단하는 경우가 많은 것

# %%
print(len(pokemon.columns))
print(pokemon.columns)
# Out:
# 45
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary', 'name_count',
#        'long_name', 'Name_nospace', 'name_isalpha', 'Forme', 'Mega', 'Mewtwo',
#        'Kyurem', 'Deoxys', 'Hoopa', 'Latias', 'Latios', 'Kyogre', 'Groudon',
#        'Grass', 'Rock', 'Ghost', 'Fire', 'Ground', 'Ice', 'Fighting',
#        'Electric', 'Dragon', 'Steel', 'Bug', 'Normal', 'Poison', 'Psychic',
#        'Flying', 'Dark', 'Water', 'Fairy'],
#       dtype='object')

# %%
features = ['Total', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 
            'name_count', 'long_name', 'Forme', 'Mega', 'Mewtwo', 'Kyurem', 'Deoxys', 'Hoopa', 
            'Latias', 'Latios', 'Kyogre', 'Groudon', 'Poison', 'Water', 'Steel', 'Grass', 
            'Bug', 'Normal', 'Fire', 'Fighting', 'Electric', 'Psychic', 'Ghost', 'Ice', 
            'Rock', 'Dark', 'Flying', 'Ground', 'Dragon', 'Fairy']

len(features)
# Out:
# 38

# %%
target = "Legendary"
target
# Out:
# 'Legendary'

# %%
X = pokemon[features]
print(X.shape)
X.head()
# Out:
# (800, 38)
#    Total  HP  Attack  Defense  Sp. Atk  ...   Dark  Flying  Ground  Dragon  Fairy
# 0    318  45      49       49       65  ...  False   False   False   False  False
# 1    405  60      62       63       80  ...  False   False   False   False  False
# 2    525  80      82       83      100  ...  False   False   False   False  False
# 3    625  80     100      123      122  ...  False   False   False   False  False
# 4    309  39      52       43       60  ...  False   False   False   False  False
#
# [5 rows x 38 columns]

# %%
y = pokemon[target]
print(y.shape)
y.head()
# Out:
# (800,)
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Legendary, dtype: bool

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=15)

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (640, 38) (640,)
# (160, 38) (160,)

# %%
model = DecisionTreeClassifier(random_state=25)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
confusion_matrix(y_test, y_pred)
# Out:
# array([[141,   6],
#        [  1,  12]])

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.99      0.96      0.98       147
#         True       0.67      0.92      0.77        13
#
#     accuracy                           0.96       160
#    macro avg       0.83      0.94      0.87       160
# weighted avg       0.97      0.96      0.96       160
